# %%
import pandas as pd
import requests
import numpy as np
import geopandas as gpd
from geopy.geocoders import Nominatim
import pandas as pd
import time
import warnings
warnings.filterwarnings('ignore')
# Get a geometry column
from shapely.geometry import Point
import folium

# %%
# Import csv file of services
services = pd.read_csv(r'C:\Users\thoma\Code\Projects\NCL Service Delivery\Service_partner_list_w_postcode.csv', index_col= [0])

# %%
# Create a list of postcodes from services
postcode_list = services['Postcode'].unique()

# Create an empty list for results
results = []

chunk_size = 10  # Define chunk size
for i in range(0, len(postcode_list), chunk_size):
    postcode_list_filtered = postcode_list[i:i+chunk_size]
    print(f"Collecting postcodes {i} to {i+len(postcode_list_filtered)-1}")

    response = requests.post(
        "https://api.postcodes.io/postcodes",
        json={"postcodes": postcode_list_filtered.tolist()}
    )

    if response.status_code == 200:
        results.append(response)
    else:
        print(f"Failed to retrieve data for chunk starting at index {i}: {response.status_code}")

# Turn the results into a list of pandas dataframes
results_dfs = [pd.json_normalize(i.json()['result'], sep='_')
for i in results]

# join all of our dataframes into a single dataframe.
postcodes_df = pd.concat(results_dfs)
# Out:
# Collecting postcodes 0 to 9
# Collecting postcodes 10 to 19
# Collecting postcodes 20 to 24

# %%
# Keep useful columns from GPS data
postcode_subset = postcodes_df[['query', 'result_postcode', 'result_quality', 'result_eastings',
       'result_northings','result_nhs_ha',
       'result_longitude', 'result_latitude',
       'result_primary_care_trust',
       'result_lsoa', 'result_msoa',
       'result_outcode', 'result_parliamentary_constituency',
       'result_codes_admin_district',
       'result_codes_admin_ward',
       'result_codes_parish', 'result_codes_parliamentary_constituency',
       'result_codes_parliamentary_constituency_2024', 'result_codes_ccg',
       'result_codes_lsoa', 'result_codes_msoa']]

# Rename column
postcode_subset.rename(columns= {'result_postcode': 'Postcode'}, inplace= True)

# %%
# Merge original dataset
full_data = services.merge(postcode_subset, on= 'Postcode')

# %%
# Initialize the geolocator to seek team coordinates
geolocator = Nominatim(user_agent="geoapi")

# Create empty list
coordinates = []

# Loop through each row and collect coordinates
for index, row in full_data.iterrows():
    service = row['Team_name']
    postcode = row['Postcode']
    try:
        # Use service name and postcode to geocode
        location = geolocator.geocode(f"{postcode}", timeout=10)
        if location:
            coordinates.append({
                'Team_name': service,
                'Postcode': postcode,
                'Latitude': location.latitude,
                'Longitude': location.longitude
            })
            print(f"Processed: {service} - ({location.latitude}, {location.longitude})")
        else:
            print(f"Location not found for: {service}, {postcode}")
            coordinates.append({
                'Team_name': service,
                'Postcode': postcode,
                'Latitude': None,
                'Longitude': None
            })
    except Exception as e:
        print(f"Error for {service}, {postcode}: {e}")
        coordinates.append({
            'Team_name': service,
            'Postcode': postcode,
            'Latitude': None,
            'Longitude': None
        })
    time.sleep(1)  # Add delay to avoid rate-limiting

# Convert results to DataFrame
coordinates_df = pd.DataFrame(coordinates)
# Out:
# Processed: Barnet Adolescent Outreach Team (Barnet AOT) - (51.59762, -0.24504)
# Processed: Barnet Adolescent Service (BAS) - (51.59762, -0.24504)
# Processed: Barnet CAMHS Crisis Service Line - (51.59762, -0.24504)
# Processed: Barnet CAMHS Generic Team - (51.59762, -0.24504)
# Processed: Barnet Children Looked After Service - (51.59762, -0.24504)
# Processed: Barnet Early Years Service - (51.59762, -0.24504)
# Processed: Barnet East and West Generic Teams - (51.59762, -0.24504)
# Processed: Barnet Integrated Clinical Services (BICS) - (51.59762, -0.24504)
# Processed: Barnet Youth Justice Service - (51.59762, -0.24504)
# Processed: Barnet Neurodevelopmental Service - (51.6066065, -0.2705674)
# Processed: Barnet, Enfield and Haringey CAMHS Single Point of Access (SPOA) - (51.6066065, -0.2705674)
# Processed: North Central London Crisis Support - (51.5358656, -0.13167885)
# Processed: Learning Disabilities and/or Autism Spectrum Disorder Keyworker Service - (51.65208, -0.08472)
# Processed: Enfield CAMHS LAC & HEART - (51.65208, -0.08472)
# Processed: Enfield CAMHS SCAN and STAY - (51.65208, -0.08472)
# Processed: Enfield Generic CAMHS and Neurodevelopmental Service (NDS) - (51.65208, -0.08472)
# Processed: Enfield Health, Education, Access and Resource Team (HEART) - (51.65208, -0.08472)
# Processed: Brandon Centre - (51.54676475, -0.144641)
# Processed: C&I Learning Disability/Autistic Spectrum Disorder (LD/ASD) Keyworker Service - (51.58053055, -0.087316175)
# Processed: Haringey Generic CAMHS - (51.58053055, -0.087316175)
# Processed: Haringey CAMHS Learning Difficulties Team - (51.58053055, -0.087316175)
# Processed: Learning Disability/Autistic Spectrum Disorder (LD/ASD) Keyworker Service - (51.58053055, -0.087316175)
# Processed: Adolescent and Young Adult Service (AYAS) - (51.5466067, -0.1753714)
# Processed: Camden Adolescent Intensive Support Service (CAISS) - (51.5466067, -0.1753714)
# Processed: Camden CAMHS LAC and Refugee - (51.5466067, -0.1753714)
# Processed: Camden CAMHS Wellbeing Team - (51.5466067, -0.1753714)
# Processed: Camden CAMHS Wellbeing Team, OpenMinded - (51.5466067, -0.1753714)
# Processed: Camden Looked After Children and Refugee Team (LAC) - (51.5466067, -0.1753714)
# Processed: Family Mental Health Team - (51.5466067, -0.1753714)
# Processed: NCL Eating Difficulties Service - (51.5466067, -0.1753714)
# Processed: North Camden Community CAMHS - (51.5466067, -0.1753714)
# Processed: North Camden Community CAMHS, OpenMinded - (51.5466067, -0.1753714)
# Processed: Mental Health Support Team in Schools - (51.5466067, -0.1753714)
# Processed: Mental Health Support Team in Schools, OpenMinded - (51.5466067, -0.1753714)
# Processed: North Central London CAMHS Dialectical Behaviour Therapy Team - (51.5466067, -0.1753714)
# Processed: Autism and Learning Disabilities Team - (51.5461577, -0.1399241)
# Processed: Camden MOSAIC - (51.5461577, -0.1399241)
# Processed: Camden Youth Justice Service - (51.534272933333334, -0.1376022)
# Processed: South Camden Community CAMHS - (51.534272933333334, -0.1376022)
# Processed: Child and Adolescent Mental Health Services Eating Disorder Service - (51.5529389, -0.1654964)
# Processed: Eating Difficulties and ARFID Service (EDAS) - (51.5529389, -0.1654964)
# Processed: NCL Eating Disorder Service - (51.5529389, -0.1654964)
# Processed: Creative Art Therapy Service (CATS) - (51.533183325, -0.12545341666666668)
# Processed: Fostering, Adoption and Kinship Care (FAKT) - (51.5501401, -0.137828)
# Processed: Gloucester House - (51.55021, -0.17445)
# Processed: Gloucester House Outreach - (51.55021, -0.17445)
# Processed: Gloucester House Outreach Service - (51.55021, -0.17445)
# Processed: Gloucester House School - (51.55021, -0.17445)
# Processed: Enfield Youth Justice Service - (51.62702, -0.04389)
# Processed: Haringey Adolescent Outreach Team (AOT) - (51.5969749, -0.1125231)
# Processed: Haringey Early Years Service - (51.5969749, -0.1125231)
# Processed: Haringey Looked After Children - (51.5969749, -0.1125231)
# Processed: Haringey Trailblazers Mental Health Support Team - (51.5969749, -0.1125231)
# Processed: Haringey Youth Justice Service - (51.5969749, -0.1125231)
# Processed: Open Door - (51.5814741, -0.1234889)
# Processed: Barnardo's Islington Social Emotional Mental Health Service - (51.53159, -0.09674)
# Processed: Islington CAMHS Adolescent Assessment and Outreach Team (AAOT) - (51.5607655, -0.1232642)
# Processed: Islington CAMHS Neurodevelopmental Team (NDT) - (51.5607655, -0.1232642)
# Processed: Islington CAMHS Children Looked After (CLA) - (51.5584599, -0.10066)
# Processed: Islington CAMHS Early Years Service (EYS) - (51.5443314, -0.1036755)
# Processed: Islington CAMHS Schools Team - (51.5443314, -0.1036755)
# Processed: Islington CAMHS Therapies Team (CTT) - (51.5443314, -0.1036755)
# Processed: Islington CAMHS: Social Emotional Mental Health Services (SEMH) - (51.5443314, -0.1036755)
# Processed: Islington Child Wellbeing Team - (51.5443314, -0.1036755)
# Processed: Islington School Wellbeing Service (SWS) - (51.5443314, -0.1036755)
# Processed: Islington Youth Justice Service (YJS) - (51.5443314, -0.1036755)
# Processed: Islington CAMHS in New River College - (51.5448406, -0.0898913)
# Processed: Islington CAMHS in New River College (NRC) Team - (51.5448406, -0.0898913)
# Processed: Islington Youth Counselling and Substance Misuse and Alcohol Service (YCSMAS) - (51.55957, -0.11124)

# %%
# Merge again with original dataset
data = full_data.merge(coordinates_df, on= 'Team_name')

# Drop duplicate column/rename other
data.drop(columns = 'Postcode_y', inplace = True)
data.rename(columns = {'Postcode_x': 'Postcode'}, inplace= True)

# Create a new geometry column that houses latitude/longitude coords
data['geometry'] = data.apply(
    lambda row: Point(row['Longitude'], row['Latitude']),
    axis=1
)

# %%
# Convert to GeoDataFrame
G_dataframe = gpd.GeoDataFrame(data, geometry='geometry')

# Define Coordinate Reference System (CRS)
G_dataframe.set_crs(epsg=4326, inplace=True)  # WGS84 CRS for latitude/longitude
# Out:
#                                             Team_name  \
# 0        Barnet Adolescent Outreach Team (Barnet AOT)
# 1                     Barnet Adolescent Service (BAS)
# 2                    Barnet CAMHS Crisis Service Line
# 3                           Barnet CAMHS Generic Team
# 4                Barnet Children Looked After Service
# ..                                                ...
# 64           Islington School Wellbeing Service (SWS)
# 65              Islington Youth Justice Service (YJS)
# 66               Islington CAMHS in New River College
# 67    Islington CAMHS in New River College (NRC) Team
# 68  Islington Youth Counselling and Substance Misu...
#
#                                              Address Postcode  \
# 0                2 Bristol Avenue, Colindale, London  NW9 4EW
# 1                2 Bristol Avenue, Colindale, London  NW9 4EW
# 2                2 Bristol Avenue, Colindale, London  NW9 4EW
# 3                2 Bristol Avenue, Colindale, London  NW9 4EW
# 4                2 Bristol Avenue, Colindale, London  NW9 4EW
# ..                                               ...      ...
# 64               222 Upper Street, Islington, London   N1 1XR
# 65               222 Upper Street, Islington, London   N1 1XR
# 66  New River College, 23-24 New River Green, London   N1 2SX
# 67  New River College, 23-24 New River Green, London   N1 2SX
# 68                           50 Isledon Road, London   N7 7LD
#
#      Category of service Borough based in  \
# 0   Adolescent intensive           Barnet
# 1   Adolescent intensive           Barnet
# 2                 Crisis           Barnet
# 3                Generic           Barnet
# 4                    LAC           Barnet
# ..                   ...              ...
# 64               Schools        Islington
# 65           Integrated         Islington
# 66               Schools        Islington
# 67               Schools        Islington
# 68           Integrated         Islington
#
#                                             Page link  \
# 0        https://www.nclwaitingroom.nhs.uk/barnet-aot
# 1                                                 NaN
# 2                                                 NaN
# 3   https://www.nclwaitingroom.nhs.uk/barnet-camhs...
# 4                                                 NaN
# ..                                                ...
# 64       https://www.nclwaitingroom.nhs.uk/icamhs-sws
# 65    https://www.nclwaitingroom.nhs.uk/islington-yjs
# 66                                                NaN
# 67       https://www.nclwaitingroom.nhs.uk/icamhs-nrc
# 68           https://www.nclwaitingroom.nhs.uk/ycsmas
#
#                            URL extension       Page owner  \
# 0                                    NaN  Helen Greenwood
# 1                                   /bas              NaN
# 2   /north-central-london-crisis-support              NaN
# 3                                    NaN     Emma Fassett
# 4                                    NaN               ??
# ..                                   ...              ...
# 64                                   NaN     Louise Jones
# 65                                   NaN    Georgie Smith
# 66                           /icamhs-nrc              NaN
# 67                                   NaN     Daryl Parker
# 68                                   NaN   Myrto Williams
#
#                        Page owner role               Page contact email  ...  \
# 0                         Team Manager             h.greenwood1@nhs.net  ...
# 1                                  NaN                              NaN  ...
# 2                                  NaN                              NaN  ...
# 3             Operational Team Manager             emma.fassett@nhs.net  ...
# 4                                   ??                               ??  ...
# ..                                 ...                              ...  ...
# 64              SWS Operations Manager    louise.jones@islington.gov.uk  ...
# 65              Senior CAMHS Clinician          georgina.smith4@nhs.net  ...
# 66                                 NaN                              NaN  ...
# 67  CAMHS in New River College Manager            daryl.parker2@nhs.net  ...
# 68                  YCSMAS Coordinator  myrto.williams@islington.gov.uk  ...
#
#    result_codes_admin_ward  result_codes_parish  \
# 0                E05013632            E43000193
# 1                E05013632            E43000193
# 2                E05013632            E43000193
# 3                E05013632            E43000193
# 4                E05013632            E43000193
# ..                     ...                  ...
# 64               E05013708            E43000209
# 65               E05013708            E43000209
# 66               E05013701            E43000209
# 67               E05013701            E43000209
# 68               E05013703            E43000209
#
#     result_codes_parliamentary_constituency  \
# 0                                 E14001279
# 1                                 E14001279
# 2                                 E14001279
# 3                                 E14001279
# 4                                 E14001279
# ..                                      ...
# 64                                E14001306
# 65                                E14001306
# 66                                E14001306
# 67                                E14001306
# 68                                E14001305
#
#     result_codes_parliamentary_constituency_2024 result_codes_ccg  \
# 0                                      E14001279        E38000240
# 1                                      E14001279        E38000240
# 2                                      E14001279        E38000240
# 3                                      E14001279        E38000240
# 4                                      E14001279        E38000240
# ..                                           ...              ...
# 64                                     E14001306        E38000240
# 65                                     E14001306        E38000240
# 66                                     E14001306        E38000240
# 67                                     E14001306        E38000240
# 68                                     E14001305        E38000240
#
#     result_codes_lsoa  result_codes_msoa   Latitude Longitude  \
# 0           E01000154          E02000049  51.597620 -0.245040
# 1           E01000154          E02000049  51.597620 -0.245040
# 2           E01000154          E02000049  51.597620 -0.245040
# 3           E01000154          E02000049  51.597620 -0.245040
# 4           E01000154          E02000049  51.597620 -0.245040
# ..                ...                ...        ...       ...
# 64          E01002795          E02000566  51.544331 -0.103676
# 65          E01002795          E02000566  51.544331 -0.103676
# 66          E01002716          E02000567  51.544841 -0.089891
# 67          E01002716          E02000567  51.544841 -0.089891
# 68          E01002730          E02000560  51.559570 -0.111240
#
#                      geometry
# 0   POINT (-0.24504 51.59762)
# 1   POINT (-0.24504 51.59762)
# 2   POINT (-0.24504 51.59762)
# 3   POINT (-0.24504 51.59762)
# 4   POINT (-0.24504 51.59762)
# ..                        ...
# 64  POINT (-0.10368 51.54433)
# 65  POINT (-0.10368 51.54433)
# 66  POINT (-0.08989 51.54484)
# 67  POINT (-0.08989 51.54484)
# 68  POINT (-0.11124 51.55957)
#
# [69 rows x 33 columns]

# %%
# Change team name for map example
G_dataframe.iloc[34, G_dataframe.columns.get_loc("Team_name")] = 'Tavistock and Portman NHS Foundation Trust'

# Extract coordinates and team names
NCL_geo = [[row.geometry.y, row.geometry.x, row.Team_name] for _, row in G_dataframe.iterrows()]

# %%
# Create a Folium map centered around the first point
NCL_map = folium.Map(location=[51.6393, -0.1910], zoom_start=14)

# Loop through the coordinates and names
for lat, lon, name in NCL_geo:  # Unpack each entry in the list
    folium.Marker(
        location=[lat, lon], 
        popup=f"Service: {name}",
        icon=folium.Icon(icon="info-sign")  # Add an icon explicitly
    ).add_to(NCL_map)

# %%
NCL_map.save('Basic.html')

# %%
# Add a chloropleth example 
stats19_choro_gdf = gpd.read_file("stats_19_counts_by_msoa_normalised_3857.geojson")

# %%
# Create choropleth for rate cyclist collisions
choropleth = folium.Choropleth(
    geo_data = stats19_choro_gdf,
    data = stats19_choro_gdf,
    columns = ['MSOA11CD', 'cyclist_casualties_2018_2022_rate'],
    key_on = 'feature.properties.MSOA11CD',
    fill_color = 'OrRd',
    fill_opacity = 0.4,
    line_weight = 0.3,
    legend_name = 'Cyclist Casulaties',
    highlight = True,
    smooth_factor = 0 
)

# Add choropleth to map
choropleth.add_to(NCL_map)

# %%
NCL_map.save('cloro.html')
